# %%
import numpy as np

# %%
class_txt_path = '/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_class_randomsampler.txt'
video_name_txt_path = '/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_video_name_list_randomsampler.txt'

# %%
class_txt_path = '/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_class_3.txt'
video_name_txt_path = '/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_video_name_list_3.txt'

# %%
with open(class_txt_path) as cf:
    class_number = cf.read().split("\n")
    
with open(video_name_txt_path) as vf:
    video_name = vf.read().split("\n")

# %%
class_number
# Out:
# ['29',
#  '180',
#  '35',
#  '105',
#  '388',
#  '230',
#  '118',
#  '326',
#  '399',
#  '110',
#  '391',
#  '152',
#  '187',
#  '88',
#  '123',
#  '223',
#  '42',
#  '130',
#  '66',
#  '369',
#  '391',
#  '374',
#  '212',
#  '27',
#  '317',
#  '32',
#  '108',
#  '56',
#  '209',
#  '6',
#  '252',
#  '270',
#  '215',
#  '227',
#  '383',
#  '53',
#  '239',
#  '157',
#  '379',
#  '184',
#  '26',
#  '137',
#  '110',
#  '10',
#  '373',
#  '339',
#  '191',
#  '349',
#  '248',
#  '139',
#  '169',
#  '19',
#  '213',
#  '71',
#  '96',
#  '45',
#  '152',
#  '336',
#  '244',
#  '302',
#  '51',
#  '89',
#  '363',
#  '378',
#  '275',
#  '391',
#  '332',
#  '122',
#  '108',
#  '71',
#  '376',
#  '305',
#  '147',
#  '323',
#  '41',
#  '328',
#  '6',
#  '313',
#  '126',
#  '5',
#  '388',
#  '338',
#  '255',
#  '205',
#  '313',
#  '370',
#  '280',
#  '59',
#  '88',
#  '49',
#  '66',
#  '342',
#  '319',
#  '380',
#  '143',
#  '48',
#  '214',
#  '54',
#  '179',
#  '111',
#  '305',
#  '200',
#  '258',
# ...

# %%
zero_number = 0
for i in range(len(class_number)):
    label = class_number[i]
    if label == '399':
        zero_number += 1
        print(video_name[i])
print(zero_number)
# Out:
# qMGREwwh4xQ_000068_000078.mp4
# GoFJb86v1pg_000000_000010.mp4
# FQ2uRXScxTo_000034_000044.mp4
# oJOMxFCKHtA_000000_000010.mp4
# tcqZLCH3TUQ_000031_000041.mp4
# 44Mak5_s6Fk_000004_000014.mp4
# AV5bPnbuR20_000019_000029.mp4
# NK-B4YivLYc_000041_000051.mp4
# XhwjI_GCOz4_000001_000011.mp4
# jdikPYRIVkk_000001_000011.mp4
# RI_zqr3ZDhk_000002_000012.mp4
# HlGpoVti28o_000009_000019.mp4
# Cj-BGLVHw4g_000062_000072.mp4
# QWZU384dsmc_000082_000092.mp4
# Nqphuc09SYc_000065_000075.mp4
# -h0RIu0ggZs_000013_000023.mp4
# Fm3ZbSnyxuI_000300_000310.mp4
# 6p1etl9DVAs_000008_000018.mp4
# PrRfO1aMTnA_000000_000010.mp4
# iGgyhAIXgFs_000026_000036.mp4
# 1L2hST8b8S8_000001_000011.mp4
# LRV8OlZjFyw_000050_000060.mp4
# MJNjtzrl5qk_000000_000010.mp4
# rbPEdPW796c_000017_000027.mp4
# p_jY0JwMNTY_000010_000020.mp4
# -ri90Xykrxg_000002_000012.mp4
# 1fvaCH_Se2Q_000428_000438.mp4
# rJkC2kg8JZM_000035_000045.mp4
# zta-Iv-xK7I_000011_000021.mp4
# YdiUTO7HBIc_000011_000021.mp4
# KbXOZPf5laY_000026_000036.mp4
# ...

# %%
a = np.loadtxt(class_txt_path) 
original_classes = []

for i in range(400):
    original_classes.append(0)
for i in range(len(a)):
    class_number_int = int(a[i])
    original_classes[class_number_int] += 1

# %%
original_classes
# Out:
# [50,
#  49,
#  50,
#  50,
#  50,
#  50,
#  49,
#  50,
#  50,
#  50,
#  50,
#  49,
#  49,
#  50,
#  50,
#  50,
#  50,
#  50,
#  49,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  51,
#  50,
#  49,
#  51,
#  50,
#  50,
#  49,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  51,
#  50,
#  49,
#  50,
#  49,
#  49,
#  50,
#  50,
#  50,
#  50,
#  50,
#  51,
#  50,
#  50,
#  49,
#  49,
#  50,
#  49,
#  50,
#  50,
#  50,
#  49,
#  50,
#  50,
#  51,
#  50,
#  50,
#  49,
#  50,
#  50,
#  48,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  49,
#  50,
#  50,
#  50,
#  49,
#  49,
#  50,
#  49,
#  49,
#  50,
#  50,
#  50,
#  49,
#  50,
#  50,
#  50,
#  49,
#  49,
#  50,
#  48,
#  50,
#  49,
#  48,
#  50,
#  44,
#  50,
#  49,
#  48,
#  49,
#  51,
#  50,
#  50,
#  49,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  48,
#  50,
#  50,
#  50,
#  49,
#  50,
#  49,
#  50,
#  49,
#  49,
#  51,
#  50,
#  49,
#  50,
#  50,
#  50,
#  50,
#  50,
#  50,
#  49,
#  50,
#  50,
# ...
