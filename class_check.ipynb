# %% [markdown]
# # ラベルと予測ラベルの差を視覚化

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/original_class.txt') 
len(a)
# Out:
# 19880

# %%
len(a)
# Out:
# 19880

# %%
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/predicted_class.txt') 
len(b)
# Out:
# 19880

# %%
b
# Out:
# array([  0., 130.,   0., ..., 394., 261.,  38.])

# %%
type(len(a))
# Out:
# int

# %%
max = 0
for i in range(len(a)):
    if max < a[i]:
        max = a[i]
print(max)
# Out:
# 399.0

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/original_class.txt') 
# b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/predicted_class.txt') 
original_classes = []
miss_classes = []
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    # if a[i] != b[i]:
    #     miss_classes[class_number] += 1

# %%
for i in range(len(original_classes)):
    print(original_classes[i])
# Out:
# 50
# 49
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 49
# 49
# 50
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 51
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 49
# 49
# 50
# 49
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 49
# 49
# 50
# 50
# 49
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 49
# 49
# 50
# 49
# 50
# 49
# 48
# 50
# 45
# 50
# 49
# 47
# 49
# 51
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# 48
# 50
# 50
# 50
# 48
# 50
# 50
# 50
# 49
# 49
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 49
# 49
# 50
# 50
# 49
# 49
# 50
# 50
# 49
# 48
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 49
# 49
# 50
# 50
# 50
# 42
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 48
# 50
# 50
# 49
# 50
# 49
# 50
# 49
# 50
# 50
# 51
# 49
# 50
# 50
# 50
# 50
# 50
# 49
# 50
# 50
# 50
# 50
# 50
# 50
# ...

# %%
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()

# %%
num_class = range(0, 400)
plt.bar(num_class, miss_classes)
plt.show()

# %% [markdown]
# # 確認ここまで
# # 下：実装

# %% [markdown]
# ## original

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/predicted_class.txt') 
original_classes = []
miss_classes = []
print('original_len', len(a))
print('predicted_len', len(b))
miss_predict = 0
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
# plt.xlim(0, 10)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 6972
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:0

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/predicted_class.txt') 
original_classes = []
miss_classes = []
print('original_len', len(a))
print('predicted_len', len(b))
miss_predict = 0
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 6955
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:10

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/10/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/10/predicted_class.txt') 
original_classes = []
miss_classes = []
print('original_len', len(a))
print('predicted_len', len(b))
miss_predict = 0
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 6935
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:20

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/predicted_class.txt') 
original_classes = []
miss_classes = []
miss_predict = 0
print('original_len', len(a))
print('predicted_len', len(b))
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 6952
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:30

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/predicted_class.txt') 
original_classes = []
miss_classes = []
miss_predict = 0
print('original_len', len(a))
print('predicted_len', len(b))
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 7075
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:40

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/40/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/40/predicted_class.txt') 
original_classes = []
miss_classes = []
miss_predict = 0
print('original_len', len(a))
print('predicted_len', len(b))
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 8009
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:50

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/50/original_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/50/predicted_class.txt') 
original_classes = []
miss_classes = []
miss_predict = 0
print('original_len', len(a))
print('predicted_len', len(b))
for i in range(400):
    original_classes.append(0)
    miss_classes.append(0)
for i in range(len(a)):
    class_number = int(a[i])
    original_classes[class_number] += 1
    if a[i] != b[i]:
        miss_classes[class_number] += 1
        miss_predict += 1

print('miss_predict', miss_predict)
num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, miss_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_len 19880
# predicted_len 19880
# miss_predict 12748
# No handles with labels found to put in legend.

# %% [markdown]
# ## 下：originalとの比較 (predict)

# %% [markdown]
# ## GOP:12, CRF:0

# %%
a = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/predicted_class.txt') 
b = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/predicted_class.txt') 

original_classes = []
predict_classes = []
print('original_predict_len', len(a))
print('compression_predict_len', len(b))
for i in range(400):
    original_classes.append(0)
    predict_classes.append(0)
for i in range(len(a)):
    class_number_original = int(a[i])
    original_classes[class_number_original] += 1
    class_number_predicted = int(b[i])
    predict_classes[class_number_predicted] += 1

num_class = range(0, 400)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        }
plt.rcParams.update(parameters) 
plt.bar(num_class, original_classes)
plt.bar(num_class, predict_classes)
plt.legend(loc=2)
plt.show()
# Out:
# original_predict_len 19880
# compression_predict_len 19880
# No handles with labels found to put in legend.

# %% [markdown]
# ## GOP:12, CRF:10

# %% [markdown]
# ## GOP:12, CRF:20

# %% [markdown]
# ## GOP:12, CRF:30

# %% [markdown]
# ## GOP:12, CRF:40

# %% [markdown]
# ## GOP:12, CRF:50

# %% [markdown]
# # 下：originalの予測率と圧縮動画での予測率

# %% [markdown]
# ## GOP:12, CRF:0

# %%
original_gt = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/original_class.txt') 
original_predeicted = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/predicted_class.txt') 
compression_gt = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/original_class.txt') 
compression_predicted = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/predicted_class.txt') 

# original_gt = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_class.txt') 
# original_predeicted = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/predicted_class.txt') 


miss_match = 0
original_gt_classes = []
original_predeict_classes = []
compression_gt_classes = []
compression_predict_classes = []
compression_miss_classes = []
print('original_gt_len', len(original_gt))
print('original_predict_len', len(original_predeicted))
print('compression_gt_len', len(compression_gt))
print('compression_predict_len', len(compression_predicted))
for i in range(400):
    original_gt_classes.append(0)
    original_predeict_classes.append(0)
    compression_gt_classes.append(0)
    compression_predict_classes.append(0)
    compression_miss_classes.append(0)
for i in range(len(original_gt)):
    class_number_gt = int(original_gt[i])
    original_gt_classes[class_number_gt] += 1
    class_number_cpre = int(compression_gt[i])
    compression_gt_classes[class_number_cpre] += 1

    if original_gt[i] == original_predeicted[i]:
        original_predeict_classes[class_number_gt] += 1
    if compression_gt[i] == compression_predicted[i]:
        compression_predict_classes[class_number_cpre] += 1
#         if original_gt[i] == compression_gt[i]:
#             if original_predeicted[i] != compression_predicted[i]:
#                 compression_miss_classes[class_number_gt] += 1
#         else:
#             miss_match += 1

# print('miss_match', miss_match)

# if  original_gt_classes == compression_gt_classes:
#     print('original_gt_classes == compression_gt_classes')
# else:
#     print('original_gt_classes != compression_gt_classes')
print(np.array_equal(original_gt_classes, compression_gt_classes))


original_predeict_classes = np.array(original_predeict_classes)
original_gt_classes = np.array(original_gt_classes)
compression_predict_classes = np.array(compression_predict_classes)
compression_gt_classes = np.array(compression_gt_classes)

original_acc = original_predeict_classes / original_gt_classes * 100
compressed_acc = compression_predict_classes / compression_gt_classes * 100

num_class = range(0, 400)
num_class = np.array(num_class)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        "legend.fontsize": 30,
        "legend.handlelength": 3
        }
# num_class_2 = num_class + 0.2
plt.rcParams.update(parameters)
x_pos = np.arange(len(num_class)) 
width = 0.35
plt.bar(x_pos - width, original_acc, width, label='original', align='edge')
plt.bar(x_pos, compressed_acc, width, label='gop:12 crf:50', align='edge')
plt.xlim(-1, 11)
plt.ylim(0, 100)
plt.legend(loc=2)
plt.show()
# Out:
# original_gt_len 19880
# original_predict_len 19880
# compression_gt_len 19880
# compression_predict_len 19880
# False

# %% [markdown]
# ## 全ての動画で一つのグラフにまとめる

# %%
original_gt = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/original_class.txt') 
original_predeicted = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/predicted_class.txt') 
compression_gt_crf0 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/original_class.txt') 
compression_predicted_crf0 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/predicted_class.txt')
compression_gt_crf10 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/10/original_class.txt') 
compression_predicted_crf10 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/10/predicted_class.txt') 
compression_gt_crf20 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_class.txt') 
compression_predicted_crf20 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/predicted_class.txt') 
compression_gt_crf30 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/original_class.txt') 
compression_predicted_crf30 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/predicted_class.txt') 
compression_gt_crf40 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/40/original_class.txt') 
compression_predicted_crf40 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/40/predicted_class.txt') 
compression_gt_crf50 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/50/original_class.txt') 
compression_predicted_crf50 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/50/predicted_class.txt') 





miss_match = 0
original_gt_classes = []
original_predeict_classes = []
compression_gt_crf0_classes = []
compression_predict_crf0_classes = []
compression_gt_crf10_classes = []
compression_predict_crf10_classes = []
compression_gt_crf20_classes = []
compression_predict_crf20_classes = []
compression_gt_crf30_classes = []
compression_predict_crf30_classes = []
compression_gt_crf40_classes = []
compression_predict_crf40_classes = []
compression_gt_crf50_classes = []
compression_predict_crf50_classes = []
# compression_miss_classes = []
print('original_gt_len', len(original_gt))
print('original_predict_len', len(original_predeicted))
print('compression_gt_crf0_len', len(compression_gt_crf0))
print('compression_predict_crf0_len', len(compression_predicted_crf0))
print('compression_gt_crf10_len', len(compression_gt_crf10))
print('compression_predict_crf10_len', len(compression_predicted_crf10))
print('compression_gt_crf20_len', len(compression_gt_crf20))
print('compression_predict_crf20_len', len(compression_predicted_crf20))
print('compression_gt_crf30_len', len(compression_gt_crf30))
print('compression_predict_crf30_len', len(compression_predicted_crf30))
print('compression_gt_crf40_len', len(compression_gt_crf40))
print('compression_predict_crf40_len', len(compression_predicted_crf40))
print('compression_gt_crf50_len', len(compression_gt_crf50))
print('compression_predict_crf50_len', len(compression_predicted_crf50))
for i in range(400):
    original_gt_classes.append(0)
    original_predeict_classes.append(0)
    compression_gt_crf0_classes.append(0)
    compression_predict_crf0_classes.append(0)
    compression_gt_crf10_classes.append(0)
    compression_predict_crf10_classes.append(0)
    compression_gt_crf20_classes.append(0)
    compression_predict_crf20_classes.append(0)
    compression_gt_crf30_classes.append(0)
    compression_predict_crf30_classes.append(0)
    compression_gt_crf40_classes.append(0)
    compression_predict_crf40_classes.append(0)
    compression_gt_crf50_classes.append(0)
    compression_predict_crf50_classes.append(0)
    # compression_miss_classes.append(0)
for i in range(len(original_gt)):
    class_number_gt = int(original_gt[i])
    original_gt_classes[class_number_gt] += 1
    class_number_gt_crf0 = int(compression_gt_crf0[i])
    compression_gt_crf0_classes[class_number_gt_crf0] += 1
    class_number_gt_crf10 = int(compression_gt_crf10[i])
    compression_gt_crf10_classes[class_number_gt_crf10] += 1
    class_number_gt_crf20 = int(compression_gt_crf20[i])
    compression_gt_crf20_classes[class_number_gt_crf20] += 1
    class_number_gt_crf30 = int(compression_gt_crf30[i])
    compression_gt_crf30_classes[class_number_gt_crf30] += 1
    class_number_gt_crf40 = int(compression_gt_crf40[i])
    compression_gt_crf40_classes[class_number_gt_crf40] += 1
    class_number_gt_crf50 = int(compression_gt_crf50[i])
    compression_gt_crf50_classes[class_number_gt_crf50] += 1

    if original_gt[i] == original_predeicted[i]:
        original_predeict_classes[class_number_gt] += 1
    if compression_gt_crf0[i] == compression_predicted_crf0[i]:
        compression_predict_crf0_classes[class_number_gt_crf0] += 1
    if compression_gt_crf10[i] == compression_predicted_crf10[i]:
        compression_predict_crf10_classes[class_number_gt_crf10] += 1
    if compression_gt_crf20[i] == compression_predicted_crf20[i]:
        compression_predict_crf20_classes[class_number_gt_crf20] += 1
    if compression_gt_crf30[i] == compression_predicted_crf30[i]:
        compression_predict_crf30_classes[class_number_gt_crf30] += 1
    if compression_gt_crf40[i] == compression_predicted_crf40[i]:
        compression_predict_crf40_classes[class_number_gt_crf40] += 1
    if compression_gt_crf50[i] == compression_predicted_crf50[i]:
        compression_predict_crf50_classes[class_number_gt_crf50] += 1

# print(np.array_equal(original_gt_classes, compression_gt_crf0_classes))


original_predeict_classes = np.array(original_predeict_classes)
original_gt_classes = np.array(original_gt_classes)
compression_predict_crf0_classes = np.array(compression_predict_crf0_classes)
compression_predict_crf10_classes = np.array(compression_predict_crf10_classes)
compression_predict_crf20_classes = np.array(compression_predict_crf20_classes)
compression_predict_crf30_classes = np.array(compression_predict_crf30_classes)
compression_predict_crf40_classes = np.array(compression_predict_crf40_classes)
compression_predict_crf50_classes = np.array(compression_predict_crf50_classes)

compression_gt_crf0_classes = np.array(compression_gt_crf0_classes)
compression_gt_crf10_classes = np.array(compression_gt_crf10_classes)
compression_gt_crf20_classes = np.array(compression_gt_crf20_classes)
compression_gt_crf30_classes = np.array(compression_gt_crf30_classes)
compression_gt_crf40_classes = np.array(compression_gt_crf40_classes)
compression_gt_crf50_classes = np.array(compression_gt_crf50_classes)

original_acc = original_predeict_classes / original_gt_classes * 100
compressed_crf0_acc = compression_predict_crf0_classes / compression_gt_crf0_classes * 100
compressed_crf10_acc = compression_predict_crf10_classes / compression_gt_crf10_classes * 100
compressed_crf20_acc = compression_predict_crf20_classes / compression_gt_crf20_classes * 100
compressed_crf30_acc = compression_predict_crf30_classes / compression_gt_crf30_classes * 100
compressed_crf40_acc = compression_predict_crf40_classes / compression_gt_crf40_classes * 100
compressed_crf50_acc = compression_predict_crf50_classes / compression_gt_crf50_classes * 100

num_class = range(0, 400)
num_class = np.array(num_class)
# plt.figure(figsize=(32,24))
parameters = {'xtick.labelsize': 40,
        'ytick.labelsize': 40,
        # 'axes.labelsize': 14,
        # 'axes.titlesize': 14,
        "figure.figsize": (32, 24),
        "legend.fontsize": 30,
        "legend.handlelength": 3
        }
# num_class_2 = num_class + 0.2
plt.rcParams.update(parameters)
x_pos = np.arange(len(num_class)) 
width = 0.1
plt.bar(x_pos - 3.5 * width, original_acc, width, label='original', align='edge')
plt.bar(x_pos - 2.5 * width, compressed_crf0_acc, width, label='GOP:12 CRF:0', align='edge')
plt.bar(x_pos - 1.5 * width, compressed_crf10_acc, width, label='GOP:12 CRF:10', align='edge')
plt.bar(x_pos - 0.5 * width, compressed_crf20_acc, width, label='GOP:12 CRF:20', align='edge')
plt.bar(x_pos + 0.5 * width, compressed_crf30_acc, width, label='GOP:12 CRF:30', align='edge')
plt.bar(x_pos + 1.5 * width, compressed_crf40_acc, width, label='GOP:12 CRF:40', align='edge')
plt.bar(x_pos + 2.5 * width, compressed_crf50_acc, width, label='GOP:12 CRF:50', align='edge')


plt.xlim(-1, 11)
plt.ylim(0, 100)
plt.legend(loc=2)
plt.show()
# Out:
# original_gt_len 19880
# original_predict_len 19880
# compression_gt_crf0_len 19880
# compression_predict_crf0_len 19880
# compression_gt_crf10_len 19880
# compression_predict_crf10_len 19880
# compression_gt_crf20_len 19880
# compression_predict_crf20_len 19880
# compression_gt_crf30_len 19880
# compression_predict_crf30_len 19880
# compression_gt_crf40_len 19880
# compression_predict_crf40_len 19880
# compression_gt_crf50_len 19880
# compression_predict_crf50_len 19880

# %%
original_gt = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/original_class.txt') 
original_predeicted = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/original/predicted_class.txt') 
compression_gt_crf0 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/original_class.txt') 
compression_predicted_crf0 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/0/predicted_class.txt')
compression_gt_crf10 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/10/original_class.txt') 
compression_predicted_crf10 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/10/predicted_class.txt') 
compression_gt_crf20 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/original_class.txt') 
compression_predicted_crf20 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/20/predicted_class.txt') 
compression_gt_crf30 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/original_class.txt') 
compression_predicted_crf30 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/30/predicted_class.txt') 
compression_gt_crf40 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/40/original_class.txt') 
compression_predicted_crf40 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/40/predicted_class.txt') 
compression_gt_crf50 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/50/original_class.txt') 
compression_predicted_crf50 = np.loadtxt('/mnt/HDD10TB-2/ohtani/pytorchvideo/class_check/gop/12/crf/50/predicted_class.txt') 





miss_match = 0
original_gt_classes = []
original_predeict_classes = []
compression_gt_crf0_classes = []
compression_predict_crf0_classes = []
compression_gt_crf10_classes = []
compression_predict_crf10_classes = []
compression_gt_crf20_classes = []
compression_predict_crf20_classes = []
compression_gt_crf30_classes = []
compression_predict_crf30_classes = []
compression_gt_crf40_classes = []
compression_predict_crf40_classes = []
compression_gt_crf50_classes = []
compression_predict_crf50_classes = []
# compression_miss_classes = []
print('original_gt_len', len(original_gt))
print('original_predict_len', len(original_predeicted))
print('compression_gt_crf0_len', len(compression_gt_crf0))
print('compression_predict_crf0_len', len(compression_predicted_crf0))
print('compression_gt_crf10_len', len(compression_gt_crf10))
print('compression_predict_crf10_len', len(compression_predicted_crf10))
print('compression_gt_crf20_len', len(compression_gt_crf20))
print('compression_predict_crf20_len', len(compression_predicted_crf20))
print('compression_gt_crf30_len', len(compression_gt_crf30))
print('compression_predict_crf30_len', len(compression_predicted_crf30))
print('compression_gt_crf40_len', len(compression_gt_crf40))
print('compression_predict_crf40_len', len(compression_predicted_crf40))
print('compression_gt_crf50_len', len(compression_gt_crf50))
print('compression_predict_crf50_len', len(compression_predicted_crf50))
for i in range(400):
    original_gt_classes.append(0)
    original_predeict_classes.append(0)
    compression_gt_crf0_classes.append(0)
    compression_predict_crf0_classes.append(0)
    compression_gt_crf10_classes.append(0)
    compression_predict_crf10_classes.append(0)
    compression_gt_crf20_classes.append(0)
    compression_predict_crf20_classes.append(0)
    compression_gt_crf30_classes.append(0)
    compression_predict_crf30_classes.append(0)
    compression_gt_crf40_classes.append(0)
    compression_predict_crf40_classes.append(0)
    compression_gt_crf50_classes.append(0)
    compression_predict_crf50_classes.append(0)
    # compression_miss_classes.append(0)
for i in range(len(original_gt)):
    class_number_gt = int(original_gt[i])
    original_gt_classes[class_number_gt] += 1
    class_number_gt_crf0 = int(compression_gt_crf0[i])
    compression_gt_crf0_classes[class_number_gt_crf0] += 1
    class_number_gt_crf10 = int(compression_gt_crf10[i])
    compression_gt_crf10_classes[class_number_gt_crf10] += 1
    class_number_gt_crf20 = int(compression_gt_crf20[i])
    compression_gt_crf20_classes[class_number_gt_crf20] += 1
    class_number_gt_crf30 = int(compression_gt_crf30[i])
    compression_gt_crf30_classes[class_number_gt_crf30] += 1
    class_number_gt_crf40 = int(compression_gt_crf40[i])
    compression_gt_crf40_classes[class_number_gt_crf40] += 1
    class_number_gt_crf50 = int(compression_gt_crf50[i])
    compression_gt_crf50_classes[class_number_gt_crf50] += 1

    if original_gt[i] == original_predeicted[i]:
        original_predeict_classes[class_number_gt] += 1
    if compression_gt_crf0[i] == compression_predicted_crf0[i]:
        compression_predict_crf0_classes[class_number_gt_crf0] += 1
    if compression_gt_crf10[i] == compression_predicted_crf10[i]:
        compression_predict_crf10_classes[class_number_gt_crf10] += 1
    if compression_gt_crf20[i] == compression_predicted_crf20[i]:
        compression_predict_crf20_classes[class_number_gt_crf20] += 1
    if compression_gt_crf30[i] == compression_predicted_crf30[i]:
        compression_predict_crf30_classes[class_number_gt_crf30] += 1
    if compression_gt_crf40[i] == compression_predicted_crf40[i]:
        compression_predict_crf40_classes[class_number_gt_crf40] += 1
    if compression_gt_crf50[i] == compression_predicted_crf50[i]:
        compression_predict_crf50_classes[class_number_gt_crf50] += 1

# print(np.array_equal(original_gt_classes, compression_gt_crf0_classes))


original_predeict_classes = np.array(original_predeict_classes)
compression_predict_crf0_classes = np.array(compression_predict_crf0_classes)
compression_predict_crf10_classes = np.array(compression_predict_crf10_classes)
compression_predict_crf20_classes = np.array(compression_predict_crf20_classes)
compression_predict_crf30_classes = np.array(compression_predict_crf30_classes)
compression_predict_crf40_classes = np.array(compression_predict_crf40_classes)
compression_predict_crf50_classes = np.array(compression_predict_crf50_classes)

original_gt_classes = np.array(original_gt_classes)
compression_gt_crf0_classes = np.array(compression_gt_crf0_classes)
compression_gt_crf10_classes = np.array(compression_gt_crf10_classes)
compression_gt_crf20_classes = np.array(compression_gt_crf20_classes)
compression_gt_crf30_classes = np.array(compression_gt_crf30_classes)
compression_gt_crf40_classes = np.array(compression_gt_crf40_classes)
compression_gt_crf50_classes = np.array(compression_gt_crf50_classes)

original_acc = original_predeict_classes / original_gt_classes * 100
compressed_crf0_acc = compression_predict_crf0_classes / compression_gt_crf0_classes * 100
compressed_crf10_acc = compression_predict_crf10_classes / compression_gt_crf10_classes * 100
compressed_crf20_acc = compression_predict_crf20_classes / compression_gt_crf20_classes * 100
compressed_crf30_acc = compression_predict_crf30_classes / compression_gt_crf30_classes * 100
compressed_crf40_acc = compression_predict_crf40_classes / compression_gt_crf40_classes * 100
compressed_crf50_acc = compression_predict_crf50_classes / compression_gt_crf50_classes * 100

num_class = range(0, 400)
num_class = np.array(num_class)
# plt.figure(figsize=(32,24))
# parameters = {'xtick.labelsize': 40,
#         'ytick.labelsize': 40,
#         # 'axes.labelsize': 14,
#         # 'axes.titlesize': 14,
#         "figure.figsize": (32, 24),
#         "legend.fontsize": 30,
#         "legend.handlelength": 3
#         }
# # num_class_2 = num_class + 0.2
# plt.rcParams.update(parameters)
# x_pos = np.arange(len(num_class)) 
# width = 0.1
# plt.bar(x_pos - 3.5 * width, original_acc, width, label='original', align='edge')
# plt.bar(x_pos - 2.5 * width, compressed_crf0_acc, width, label='GOP:12 CRF:0', align='edge')
# plt.bar(x_pos - 1.5 * width, compressed_crf10_acc, width, label='GOP:12 CRF:10', align='edge')
# plt.bar(x_pos - 0.5 * width, compressed_crf20_acc, width, label='GOP:12 CRF:20', align='edge')
# plt.bar(x_pos + 0.5 * width, compressed_crf30_acc, width, label='GOP:12 CRF:30', align='edge')
# plt.bar(x_pos + 1.5 * width, compressed_crf40_acc, width, label='GOP:12 CRF:40', align='edge')
# plt.bar(x_pos + 2.5 * width, compressed_crf50_acc, width, label='GOP:12 CRF:50', align='edge')


# plt.xlim(-1, 11)
# plt.ylim(0, 100)
# plt.legend(loc=2)
# plt.show()
# Out:
# original_gt_len 19880
# original_predict_len 19880
# compression_gt_crf0_len 19880
# compression_predict_crf0_len 19880
# compression_gt_crf10_len 19880
# compression_predict_crf10_len 19880
# compression_gt_crf20_len 19880
# compression_predict_crf20_len 19880
# compression_gt_crf30_len 19880
# compression_predict_crf30_len 19880
# compression_gt_crf40_len 19880
# compression_predict_crf40_len 19880
# compression_gt_crf50_len 19880
# compression_predict_crf50_len 19880

# %%
acc = []
original = (original_acc / original_acc) * 100
acc.append(original)
crf0 = (compressed_crf0_acc / original_acc) * 100
acc.append(crf0)
crf10 = (compressed_crf10_acc / original_acc) * 100
acc.append(crf10)
crf20 = (compressed_crf20_acc / original_acc) * 100
acc.append(crf20)
crf30 = (compressed_crf30_acc / original_acc) * 100
acc.append(crf30)
crf40 = (compressed_crf40_acc / original_acc) * 100
acc.append(crf40)
crf50 = (compressed_crf50_acc / original_acc) * 100
acc.append(crf50)

# %%
acc = []
original = original_acc / original_acc
acc.append(original)
crf0 = compressed_crf0_acc / original_acc 
acc.append(crf0)
crf10 = compressed_crf10_acc / original_acc 
acc.append(crf10)
crf20 = compressed_crf20_acc / original_acc 
acc.append(crf20)
crf30 = compressed_crf30_acc / original_acc
acc.append(crf30)
crf40 = compressed_crf40_acc / original_acc 
acc.append(crf40)
crf50 = compressed_crf50_acc / original_acc 
acc.append(crf50)

# %%
len(acc)
# Out:
# 7

# %%
acc[0]
# Out:
# array([100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
# ...

# %%
labels = list(range(-10, 60, 10))
parameters = {'xtick.labelsize': 16,
        'ytick.labelsize': 16,
        'axes.labelsize': 16,
        'axes.titlesize': 16,
        "figure.figsize": (8, 5),
        }
# num_class_2 = num_class + 0.2
plt.rcParams.update(parameters)
boxplt = plt.boxplot(acc, labels=labels, patch_artist=True, showmeans=True)
plt.xlabel('CRF')
plt.ylabel('relative accuracy')
# plt.title('accuracy for each class')
plt.savefig('acc_fig/ffmpeg/x3d_m/accuracy_for_each_class.pdf')
plt.show()

# %%
acc = np.array(acc)

# %%
type(acc)
# Out:
# numpy.ndarray

# %%
row_indices = ['-10', '0', '10', '20', '30', '40', '50']
data_df = pd.DataFrame(acc, index=row_indices)

# %%
print(data_df)
# Out:
#             0      1           2           3       4           5    \
# -10  100.000000  100.0  100.000000  100.000000  100.00  100.000000
# 0    100.000000  100.0  114.333333  100.000000  102.00  100.000000
# 10    95.389507  100.0  106.166667  100.000000  106.25  100.000000
# 20   100.000000   92.0  122.500000  100.000000  106.25   97.058824
# 30    94.594595   96.0   81.666667  102.040816   97.75  100.000000
# 40    72.972973   96.0   65.333333   94.444444   89.25   85.294118
# 50    21.621622   68.0   24.500000   55.555556   51.00   41.176471
#
#             6           7           8           9    ...         390  \
# -10  100.000000  100.000000  100.000000  100.000000  ...  100.000000
# 0    100.000000   97.826087  100.000000  103.448276  ...  100.000000
# 10    98.000000   97.826087  100.000000  110.344828  ...  100.000000
# 20    96.848291   97.826087  100.000000  113.793103  ...   97.560976
# 30    97.435897  100.000000  100.000000  106.896552  ...   92.682927
# ...

# %%
labels = list(range(-10, 60, 10))
fig = plt.figure()


# sns.boxplot(x=labels, y=acc, showfilters=False, palette='Set3', ax=ax)
sns.stripplot(x=labels, y=acc, data=acc, dodge=True, jitter=True, color='black', ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3905570/3549864420.py in <module>
#       5
#       6 # sns.boxplot(x=labels, y=acc, showfilters=False, palette='Set3', ax=ax)
# ----> 7 sns.stripplot(x=labels, y=acc, data=acc, dodge=True, jitter=True, color='black', ax=ax)
#       8 plt.show()
#
# /opt/conda/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /opt/conda/lib/python3.8/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2805         warnings.warn(msg, UserWarning)
#    2806
# ...
