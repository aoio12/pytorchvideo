# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import glob
import os
# %matplotlib inline

# %%
df = pd.read_csv('../../dataset_info/gop/12/filesize_crf50.txt',
                 names=['filesize'])

filesize = df.values
filesize_sum = np.sum(filesize) / 1000000000
print(len(filesize))
print(filesize_sum)
# Out:
# 19881
# 4.059547979

# %%
df = pd.read_csv('../../dataset_info/filesize_val.txt',
                 names=['filesize']
                )
# df = pd.read_csv(file_path, names=['filesize'])
ax = df.plot.hist(bins=200)
ax.set_xlabel('file size [Byte]');
ax.set_xscale('log')
ax.set_xlim([10**3,10**8])    #X軸の範囲を設定
ax.set_ylim(0, 800)

parameters = {'xtick.labelsize': 16,
        'ytick.labelsize': 16,
        'axes.labelsize': 16,
        'axes.titlesize': 16,
        'figure.figsize': (8,6),}
plt.rcParams.update(parameters)
plt.savefig("filesize_fig/original_filesize.pdf")

# %%
# files = glob.glob("/mnt/HDD10TB-2/ohtani/dataset_info/gop/1/stream_info_crf*.txt")
gops = ["1", "2", "5", "10", "12"]
crfs = ["0", "10", "20", "30", "40", "50"]

for gop in gops:
        for crf in crfs:
                txt_search = "file_path = '/mnt/HDD10TB-2/ohtani/dataset_info/gop/" + str(gop) + "/filesize_crf" + str(crf) + ".txt'"
                exec(txt_search)
                # l_in = [s for s in files if txt_file in s]
                # print(l_in)
                print(file_path)
                df = pd.read_csv(file_path, names=['filesize'])
                ax = df.plot.hist(bins=200)
                ax.set_xlabel('file size [Byte]');
                ax.set_xscale('log')
                ax.set_xlim([10**3-100,10**8])    #X軸の範囲を設定
                ax.set_ylim(0, 800)

                parameters = {'xtick.labelsize': 16,
                        'ytick.labelsize': 16,
                        'axes.labelsize': 16,
                        'axes.titlesize': 16,
                        'figure.figsize': (8,6),}
                plt.rcParams.update(parameters)
                fig_save = 'plt.savefig("filesize_fig/gop/' + str(gop) + '/filesize_gop' + str(gop) + 'crf' + str(crf) + '.pdf")'
                exec(fig_save) 
                plt.show()
# Out:
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/1/filesize_crf0.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/1/filesize_crf10.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/1/filesize_crf20.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/1/filesize_crf30.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/1/filesize_crf40.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/1/filesize_crf50.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/2/filesize_crf0.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/2/filesize_crf10.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/2/filesize_crf20.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/2/filesize_crf30.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/2/filesize_crf40.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/2/filesize_crf50.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/5/filesize_crf0.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/5/filesize_crf10.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/5/filesize_crf20.txt
# /mnt/HDD10TB-2/ohtani/dataset_info/gop/5/filesize_crf30.txt
# ...
